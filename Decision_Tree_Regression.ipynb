# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


import warnings 
warnings.filterwarnings('ignore')

# %%
from sklearn.datasets import fetch_california_housing
data = fetch_california_housing()
df=pd.DataFrame(data.data,columns =data.feature_names)

# %%
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# 1        -122.22
# 2        -122.24
# 3        -122.25
# 4        -122.25
# ...          ...
# 20635    -121.09
# 20636    -121.21
# 20637    -121.22
# 20638    -121.32
# 20639    -121.24
#
# [20640 rows x 8 columns]

# %%
df['price']=data.target

# %%
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  price
# 0        -122.23  4.526
# 1        -122.22  3.585
# 2        -122.24  3.521
# 3        -122.25  3.413
# 4        -122.25  3.422
# ...          ...    ...
# 20635    -121.09  0.781
# 20636    -121.21  0.771
# 20637    -121.22  0.923
# 20638    -121.32  0.847
# 20639    -121.24  0.894
#
# [20640 rows x 9 columns]

# %%
df=df.sample(frac = 0.20)

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
x
# Out:
#         MedInc  HouseAge   AveRooms  AveBedrms  Population  AveOccup  \
# 18668   4.8693      23.0   6.448864   1.095455      2197.0  2.496591
# 9692    2.7367      21.0   4.108390   1.047942      4907.0  2.557061
# 8182    5.0574      37.0   5.530488   1.003049       850.0  2.591463
# 12220   5.2066       4.0  10.500000   1.445652       311.0  3.380435
# 11952   4.3750      33.0   6.039648   1.039648       715.0  3.149780
# ...        ...       ...        ...        ...         ...       ...
# 11008  10.1714       6.0   8.305344   1.088210      3744.0  3.175573
# 5406    3.1250      30.0   3.791971   1.105839       606.0  2.211679
# 3594    5.0232      30.0   6.268559   1.026201      1335.0  2.914847
# 11183   3.4000      27.0   4.203077   1.003077       878.0  2.701538
# 17985   3.3958      25.0   4.000709   1.075887      3786.0  2.685106
#
#        Latitude  Longitude
# 18668     36.99    -121.91
# 9692      36.69    -121.65
# 8182      33.80    -118.10
# 12220     33.51    -117.32
# 11952     33.93    -117.44
# ...         ...        ...
# 11008     33.78    -117.78
# 5406      34.03    -118.44
# 3594      34.25    -118.49
# 11183     33.82    -117.94
# 17985     37.30    -121.95
#
# [4128 rows x 8 columns]

# %%
y
# Out:
# 18668    3.22300
# 9692     1.60300
# 8182     2.40800
# 12220    5.00001
# 11952    1.29900
#           ...
# 11008    4.81500
# 5406     3.43800
# 3594     2.53900
# 11183    1.96900
# 17985    2.67500
# Name: price, Length: 4128, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=1)

# %%
from sklearn.tree import DecisionTreeRegressor
model= DecisionTreeRegressor()
model
# Out:
# DecisionTreeRegressor()

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([0.532, 2.361, 1.588, ..., 3.482, 3.428, 3.335])

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.5253544534244347

# %%
parameter = {
    'criterion':['squared_error','poisson'],
    'max_depth':[1,2,3,4,6,8],
    'splitter':["best","random"],
    "max_features" : ["sqrt","log2"]
}
reg=DecisionTreeRegressor()

# %%
from sklearn.model_selection import GridSearchCV


model = GridSearchCV(
    estimator=reg, 
    param_grid=parameter, 
    cv=5, 
    scoring="neg_mean_squared_error"  
)

# %%
model
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(),
#              param_grid={'criterion': ['squared_error', 'poisson'],
#                          'max_depth': [1, 2, 3, 4, 6, 8],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              scoring='neg_mean_squared_error')

# %%
model.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(),
#              param_grid={'criterion': ['squared_error', 'poisson'],
#                          'max_depth': [1, 2, 3, 4, 6, 8],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              scoring='neg_mean_squared_error')

# %%
model.best_params_
# Out:
# {'criterion': 'squared_error',
#  'max_depth': 6,
#  'max_features': 'log2',
#  'splitter': 'best'}

# %%
final_model = DecisionTreeRegressor(criterion = "squared_error",max_depth=8)

# %%
final_model.fit(x_train ,y_train)
# Out:
# DecisionTreeRegressor(max_depth=8)

# %%
from sklearn import tree
plt.figure(figsize=(12,10))
tree.plot_tree(final_model,filled=True)
# Out:
# [Text(0.5298807989690721, 0.9444444444444444, 'x[0] <= 5.036\nsquared_error = 1.265\nsamples = 2889\nvalue = 2.065'),
#  Text(0.25620167525773196, 0.8333333333333334, 'x[0] <= 2.912\nsquared_error = 0.716\nsamples = 2260\nvalue = 1.722'),
#  Text(0.12016752577319588, 0.7222222222222222, 'x[2] <= 3.854\nsquared_error = 0.491\nsamples = 965\nvalue = 1.323'),
#  Text(0.06024484536082474, 0.6111111111111112, 'x[5] <= 3.41\nsquared_error = 0.658\nsamples = 239\nvalue = 1.765'),
#  Text(0.03286082474226804, 0.5, 'x[6] <= 37.825\nsquared_error = 0.693\nsamples = 148\nvalue = 1.949'),
#  Text(0.014175257731958763, 0.3888888888888889, 'x[5] <= 1.545\nsquared_error = 0.693\nsamples = 131\nvalue = 2.031'),
#  Text(0.007731958762886598, 0.2777777777777778, 'x[5] <= 1.519\nsquared_error = 0.509\nsamples = 5\nvalue = 3.4'),
#  Text(0.005154639175257732, 0.16666666666666666, 'x[3] <= 1.025\nsquared_error = 0.199\nsamples = 4\nvalue = 3.104'),
#  Text(0.002577319587628866, 0.05555555555555555, 'squared_error = 0.0\nsamples = 1\nvalue = 2.417'),
#  Text(0.007731958762886598, 0.05555555555555555, 'squared_error = 0.056\nsamples = 3\nvalue = 3.333'),
#  Text(0.010309278350515464, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 4.583'),
#  Text(0.020618556701030927, 0.2777777777777778, 'x[6] <= 33.995\nsquared_error = 0.623\nsamples = 126\nvalue = 1.977'),
#  Text(0.015463917525773196, 0.16666666666666666, 'x[3] <= 1.222\nsquared_error = 0.247\nsamples = 46\nvalue = 1.663'),
#  Text(0.01288659793814433, 0.05555555555555555, 'squared_error = 0.176\nsamples = 45\nvalue = 1.622'),
#  Text(0.01804123711340206, 0.05555555555555555, 'squared_error = 0.0\nsamples = 1\nvalue = 3.5'),
#  Text(0.02577319587628866, 0.16666666666666666, 'x[6] <= 34.125\nsquared_error = 0.75\nsamples = 80\nvalue = 2.157'),
#  Text(0.023195876288659795, 0.05555555555555555, 'squared_error = 0.763\nsamples = 31\nvalue = 2.529'),
#  Text(0.028350515463917526, 0.05555555555555555, 'squared_error = 0.598\nsamples = 49\nvalue = 1.922'),
#  Text(0.05154639175257732, 0.3888888888888889, 'x[7] <= -121.475\nsquared_error = 0.242\nsamples = 17\nvalue = 1.32'),
#  Text(0.041237113402061855, 0.2777777777777778, 'x[1] <= 51.5\nsquared_error = 0.199\nsamples = 11\nvalue = 1.56'),
#  Text(0.03608247422680412, 0.16666666666666666, 'x[4] <= 277.0\nsquared_error = 0.057\nsamples = 8\nvalue = 1.363'),
#  Text(0.03350515463917526, 0.05555555555555555, 'squared_error = 0.0\nsamples = 1\nvalue = 0.875'),
#  Text(0.03865979381443299, 0.05555555555555555, 'squared_error = 0.026\nsamples = 7\nvalue = 1.433'),
#  Text(0.04639175257731959, 0.16666666666666666, 'x[4] <= 486.0\nsquared_error = 0.202\nsamples = 3\nvalue = 2.083'),
#  Text(0.04381443298969072, 0.05555555555555555, 'squared_error = 0.011\nsamples = 2\nvalue = 1.771'),
#  Text(0.04896907216494845, 0.05555555555555555, 'squared_error = -0.0\nsamples = 1\nvalue = 2.708'),
#  Text(0.061855670103092786, 0.2777777777777778, 'x[6] <= 38.62\nsquared_error = 0.02\nsamples = 6\nvalue = 0.879'),
#  Text(0.05670103092783505, 0.16666666666666666, 'x[7] <= -121.38\nsquared_error = 0.011\nsamples = 4\nvalue = 0.802'),
#  Text(0.05412371134020619, 0.05555555555555555, 'squared_error = 0.0\nsamples = 1\nvalue = 0.658'),
#  Text(0.059278350515463915, 0.05555555555555555, 'squared_error = 0.005\nsamples = 3\nvalue = 0.849'),
#  Text(0.06701030927835051, 0.16666666666666666, 'x[4] <= 696.5\nsquared_error = 0.002\nsamples = 2\nvalue = 1.035'),
#  Text(0.06443298969072164, 0.05555555555555555, 'squared_error = 0.0\nsamples = 1\nvalue = 1.083'),
#  Text(0.06958762886597938, 0.05555555555555555, 'squared_error = 0.0\nsamples = 1\nvalue = 0.987'),
#  Text(0.08762886597938144, 0.5, 'x[7] <= -122.24\nsquared_error = 0.458\nsamples = 91\nvalue = 1.466'),
#  Text(0.07731958762886598, 0.3888888888888889, 'x[6] <= 37.915\nsquared_error = 2.571\nsamples = 4\nvalue = 3.645'),
#  Text(0.07474226804123711, 0.2777777777777778, 'x[4] <= 1682.5\nsquared_error = 0.5\nsamples = 3\nvalue = 4.5'),
#  Text(0.07216494845360824, 0.16666666666666666, 'squared_error = 0.0\nsamples = 2\nvalue = 5.0'),
#  Text(0.07731958762886598, 0.16666666666666666, 'squared_error = -0.0\nsamples = 1\nvalue = 3.5'),
#  Text(0.07989690721649484, 0.2777777777777778, 'squared_error = 0.0\nsamples = 1\nvalue = 1.078'),
#  Text(0.0979381443298969, 0.3888888888888889, 'x[1] <= 38.5\nsquared_error = 0.132\nsamples = 87\nvalue = 1.366'),
#  Text(0.08762886597938144, 0.2777777777777778, 'x[3] <= 1.164\nsquared_error = 0.143\nsamples = 52\nvalue = 1.492'),
#  Text(0.08247422680412371, 0.16666666666666666, 'x[0] <= 1.833\nsquared_error = 0.109\nsamples = 50\nvalue = 1.454'),
#  Text(0.07989690721649484, 0.05555555555555555, 'squared_error = 0.105\nsamples = 16\nvalue = 1.263'),
#  Text(0.08505154639175258, 0.05555555555555555, 'squared_error = 0.086\nsamples = 34\nvalue = 1.544'),
#  Text(0.09278350515463918, 0.16666666666666666, 'x[2] <= 2.217\nsquared_error = 0.071\nsamples = 2\nvalue = 2.434'),
#  Text(0.09020618556701031, 0.05555555555555555, 'squared_error = 0.0\nsamples = 1\nvalue = 2.167'),
#  Text(0.09536082474226804, 0.05555555555555555, 'squared_error = 0.0\nsamples = 1\nvalue = 2.7'),
#  Text(0.10824742268041238, 0.2777777777777778, 'x[0] <= 2.118\nsquared_error = 0.057\nsamples = 35\nvalue = 1.178'),
#  Text(0.10309278350515463, 0.16666666666666666, 'x[7] <= -117.745\nsquared_error = 0.02\nsamples = 16\nvalue = 1.005'),
#  Text(0.10051546391752578, 0.05555555555555555, 'squared_error = 0.013\nsamples = 13\nvalue = 1.049'),
#  Text(0.1056701030927835, 0.05555555555555555, 'squared_error = 0.006\nsamples = 3\nvalue = 0.815'),
#  Text(0.1134020618556701, 0.16666666666666666, 'x[0] <= 2.171\nsquared_error = 0.043\nsamples = 19\nvalue = 1.323'),
#  Text(0.11082474226804123, 0.05555555555555555, 'squared_error = 0.002\nsamples = 4\nvalue = 1.591'),
#  Text(0.11597938144329897, 0.05555555555555555, 'squared_error = 0.029\nsamples = 15\nvalue = 1.251'),
#  Text(0.180090206185567, 0.6111111111111112, 'x[5] <= 2.248\nsquared_error = 0.35\nsamples = 726\nvalue = 1.178'),
#  Text(0.14432989690721648, 0.5, 'x[0] <= 2.667\nsquared_error = 0.684\nsamples = 117\nvalue = 1.613'),
#  Text(0.13015463917525774, 0.3888888888888889, 'x[0] <= 1.158\nsquared_error = 0.511\nsamples = 91\nvalue = 1.436'),
#  Text(0.1211340206185567, 0.2777777777777778, 'x[2] <= 4.641\nsquared_error = 0.264\nsamples = 3\nvalue = 2.833'),
#  Text(0.11855670103092783, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 3.5'),
#  Text(0.12371134020618557, 0.16666666666666666, 'x[4] <= 164.5\nsquared_error = 0.062\nsamples = 2\nvalue = 2.5'),
#  Text(0.1211340206185567, 0.05555555555555555, 'squared_error = 0.0\nsamples = 1\nvalue = 2.25'),
#  Text(0.12628865979381443, 0.05555555555555555, 'squared_error = 0.0\nsamples = 1\nvalue = 2.75'),
#  Text(0.13917525773195877, 0.2777777777777778, 'x[1] <= 43.0\nsquared_error = 0.451\nsamples = 88\nvalue = 1.388'),
#  Text(0.13402061855670103, 0.16666666666666666, 'x[0] <= 1.756\nsquared_error = 0.341\nsamples = 70\nvalue = 1.26'),
#  Text(0.13144329896907217, 0.05555555555555555, 'squared_error = 0.133\nsamples = 17\nvalue = 0.816'),
#  Text(0.13659793814432988, 0.05555555555555555, 'squared_error = 0.324\nsamples = 53\nvalue = 1.403'),
#  Text(0.14432989690721648, 0.16666666666666666, 'x[7] <= -122.37\nsquared_error = 0.566\nsamples = 18\nvalue = 1.886'),
#  Text(0.14175257731958762, 0.05555555555555555, 'squared_error = 0.281\nsamples = 2\nvalue = 3.113'),
#  Text(0.14690721649484537, 0.05555555555555555, 'squared_error = 0.39\nsamples = 16\nvalue = 1.733'),
#  Text(0.15850515463917525, 0.3888888888888889, 'x[0] <= 2.682\nsquared_error = 0.793\nsamples = 26\nvalue = 2.234'),
#  Text(0.15206185567010308, 0.2777777777777778, 'x[1] <= 40.0\nsquared_error = 0.788\nsamples = 2\nvalue = 4.012'),
#  Text(0.14948453608247422, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 3.125'),
#  Text(0.15463917525773196, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 4.9'),
#  Text(0.16494845360824742, 0.2777777777777778, 'x[3] <= 1.103\nsquared_error = 0.508\nsamples = 24\nvalue = 2.086'),
#  Text(0.15979381443298968, 0.16666666666666666, 'x[5] <= 1.673\nsquared_error = 0.306\nsamples = 19\nvalue = 1.854'),
#  Text(0.15721649484536082, 0.05555555555555555, 'squared_error = 0.115\nsamples = 4\nvalue = 1.242'),
#  Text(0.16237113402061856, 0.05555555555555555, 'squared_error = 0.23\nsamples = 15\nvalue = 2.017'),
#  Text(0.17010309278350516, 0.16666666666666666, 'x[3] <= 1.231\nsquared_error = 0.291\nsamples = 5\nvalue = 2.968'),
#  Text(0.16752577319587628, 0.05555555555555555, 'squared_error = 0.223\nsamples = 4\nvalue = 2.8'),
#  Text(0.17268041237113402, 0.05555555555555555, 'squared_error = -0.0\nsamples = 1\nvalue = 3.64'),
#  Text(0.21585051546391754, 0.5, 'x[0] <= 2.057\nsquared_error = 0.243\nsamples = 609\nvalue = 1.094'),
#  Text(0.1958762886597938, 0.3888888888888889, 'x[6] <= 34.105\nsquared_error = 0.141\nsamples = 222\nvalue = 0.862'),
#  Text(0.18556701030927836, 0.2777777777777778, 'x[7] <= -118.315\nsquared_error = 0.155\nsamples = 80\nvalue = 1.064'),
#  Text(0.18041237113402062, 0.16666666666666666, 'x[7] <= -118.325\nsquared_error = 0.655\nsamples = 4\nvalue = 1.873'),
#  Text(0.17783505154639176, 0.05555555555555555, 'squared_error = 0.002\nsamples = 3\nvalue = 1.406'),
#  Text(0.18298969072164947, 0.05555555555555555, 'squared_error = 0.0\nsamples = 1\nvalue = 3.273'),
#  Text(0.19072164948453607, 0.16666666666666666, 'x[7] <= -116.845\nsquared_error = 0.093\nsamples = 76\nvalue = 1.022'),
#  Text(0.18814432989690721, 0.05555555555555555, 'squared_error = 0.08\nsamples = 65\nvalue = 1.084'),
#  Text(0.19329896907216496, 0.05555555555555555, 'squared_error = 0.011\nsamples = 11\nvalue = 0.656'),
#  Text(0.20618556701030927, 0.2777777777777778, 'x[7] <= -119.985\nsquared_error = 0.096\nsamples = 142\nvalue = 0.748'),
#  Text(0.20103092783505155, 0.16666666666666666, 'x[6] <= 37.935\nsquared_error = 0.116\nsamples = 88\nvalue = 0.842'),
#  Text(0.19845360824742267, 0.05555555555555555, 'squared_error = 0.181\nsamples = 28\nvalue = 1.07'),
#  Text(0.2036082474226804, 0.05555555555555555, 'squared_error = 0.049\nsamples = 60\nvalue = 0.735'),
#  Text(0.211340206185567, 0.16666666666666666, 'x[4] <= 386.0\nsquared_error = 0.027\nsamples = 54\nvalue = 0.596'),
#  Text(0.20876288659793815, 0.05555555555555555, 'squared_error = 0.0\nsamples = 1\nvalue = 1.5'),
#  Text(0.21391752577319587, 0.05555555555555555, 'squared_error = 0.012\nsamples = 53\nvalue = 0.579'),
#  Text(0.23582474226804123, 0.3888888888888889, 'x[2] <= 4.18\nsquared_error = 0.253\nsamples = 387\nvalue = 1.227'),
#  Text(0.2268041237113402, 0.2777777777777778, 'x[6] <= 34.075\nsquared_error = 0.177\nsamples = 45\nvalue = 1.646'),
#  Text(0.22164948453608246, 0.16666666666666666, 'x[7] <= -118.395\nsquared_error = 0.149\nsamples = 28\nvalue = 1.474'),
#  Text(0.2190721649484536, 0.05555555555555555, 'squared_error = 0.0\nsamples = 1\nvalue = 3.0'),
#  Text(0.22422680412371135, 0.05555555555555555, 'squared_error = 0.065\nsamples = 27\nvalue = 1.417'),
#  Text(0.23195876288659795, 0.16666666666666666, 'x[0] <= 2.436\nsquared_error = 0.095\nsamples = 17\nvalue = 1.93'),
#  Text(0.22938144329896906, 0.05555555555555555, 'squared_error = 0.026\nsamples = 3\nvalue = 2.348'),
#  Text(0.2345360824742268, 0.05555555555555555, 'squared_error = 0.064\nsamples = 14\nvalue = 1.841'),
#  Text(0.24484536082474226, 0.2777777777777778, 'x[2] <= 21.02\nsquared_error = 0.237\nsamples = 342\nvalue = 1.172'),
#  Text(0.2422680412371134, 0.16666666666666666, 'x[0] <= 2.519\nsquared_error = 0.21\nsamples = 341\nvalue = 1.164'),
#  Text(0.23969072164948454, 0.05555555555555555, 'squared_error = 0.15\nsamples = 165\nvalue = 1.032'),
#  Text(0.24484536082474226, 0.05555555555555555, 'squared_error = 0.236\nsamples = 176\nvalue = 1.287'),
#  Text(0.24742268041237114, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 4.2'),
#  Text(0.39223582474226804, 0.7222222222222222, 'x[5] <= 2.46\nsquared_error = 0.677\nsamples = 1295\nvalue = 2.019'),
#  Text(0.3176546391752577, 0.6111111111111112, 'x[1] <= 27.5\nsquared_error = 1.033\nsamples = 361\nvalue = 2.491'),
#  Text(0.28414948453608246, 0.5, 'x[6] <= 37.835\nsquared_error = 0.498\nsamples = 169\nvalue = 2.096'),
#  Text(0.26804123711340205, 0.3888888888888889, 'x[7] <= -117.24\nsquared_error = 0.504\nsamples = 133\nvalue = 2.204'),
#  Text(0.25773195876288657, 0.2777777777777778, 'x[1] <= 23.5\nsquared_error = 0.487\nsamples = 109\nvalue = 2.337'),
#  Text(0.25257731958762886, 0.16666666666666666, 'x[5] <= 1.439\nsquared_error = 0.528\nsamples = 81\nvalue = 2.23'),
#  Text(0.25, 0.05555555555555555, 'squared_error = 1.668\nsamples = 2\nvalue = 3.709'),
#  Text(0.2551546391752577, 0.05555555555555555, 'squared_error = 0.442\nsamples = 79\nvalue = 2.192'),
#  Text(0.26288659793814434, 0.16666666666666666, 'x[2] <= 4.93\nsquared_error = 0.24\nsamples = 28\nvalue = 2.646'),
#  Text(0.2603092783505155, 0.05555555555555555, 'squared_error = 0.14\nsamples = 23\nvalue = 2.792'),
#  Text(0.2654639175257732, 0.05555555555555555, 'squared_error = 0.155\nsamples = 5\nvalue = 1.977'),
#  Text(0.27835051546391754, 0.2777777777777778, 'x[0] <= 3.884\nsquared_error = 0.142\nsamples = 24\nvalue = 1.602'),
#  Text(0.27319587628865977, 0.16666666666666666, 'x[7] <= -117.155\nsquared_error = 0.048\nsamples = 15\nvalue = 1.416'),
#  Text(0.2706185567010309, 0.05555555555555555, 'squared_error = 0.029\nsamples = 7\nvalue = 1.583'),
#  Text(0.2757731958762887, 0.05555555555555555, 'squared_error = 0.02\nsamples = 8\nvalue = 1.27'),
#  Text(0.28350515463917525, 0.16666666666666666, 'x[7] <= -117.195\nsquared_error = 0.143\nsamples = 9\nvalue = 1.913'),
#  Text(0.2809278350515464, 0.05555555555555555, 'squared_error = 0.0\nsamples = 1\nvalue = 2.778'),
#  Text(0.2860824742268041, 0.05555555555555555, 'squared_error = 0.055\nsamples = 8\nvalue = 1.804'),
#  Text(0.3002577319587629, 0.3888888888888889, 'x[7] <= -122.54\nsquared_error = 0.268\nsamples = 36\nvalue = 1.694'),
#  Text(0.2912371134020619, 0.2777777777777778, 'x[3] <= 1.032\nsquared_error = 0.06\nsamples = 6\nvalue = 2.435'),
#  Text(0.28865979381443296, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 1.944'),
#  Text(0.29381443298969073, 0.16666666666666666, 'x[4] <= 973.5\nsquared_error = 0.014\nsamples = 5\nvalue = 2.534'),
#  Text(0.2912371134020619, 0.05555555555555555, 'squared_error = 0.0\nsamples = 2\nvalue = 2.398'),
#  Text(0.2963917525773196, 0.05555555555555555, 'squared_error = 0.002\nsamples = 3\nvalue = 2.624'),
#  Text(0.30927835051546393, 0.2777777777777778, 'x[2] <= 5.032\nsquared_error = 0.177\nsamples = 30\nvalue = 1.546'),
#  Text(0.30412371134020616, 0.16666666666666666, 'x[3] <= 1.005\nsquared_error = 0.141\nsamples = 11\nvalue = 1.235'),
#  Text(0.3015463917525773, 0.05555555555555555, 'squared_error = 0.05\nsamples = 4\nvalue = 1.606'),
#  Text(0.30670103092783507, 0.05555555555555555, 'squared_error = 0.069\nsamples = 7\nvalue = 1.022'),
#  Text(0.31443298969072164, 0.16666666666666666, 'x[5] <= 2.399\nsquared_error = 0.11\nsamples = 19\nvalue = 1.727'),
#  Text(0.3118556701030928, 0.05555555555555555, 'squared_error = 0.062\nsamples = 13\nvalue = 1.834'),
#  Text(0.3170103092783505, 0.05555555555555555, 'squared_error = 0.133\nsamples = 6\nvalue = 1.493'),
#  Text(0.35115979381443296, 0.5, 'x[5] <= 1.806\nsquared_error = 1.246\nsamples = 192\nvalue = 2.839'),
#  Text(0.33118556701030927, 0.3888888888888889, 'x[7] <= -122.29\nsquared_error = 0.948\nsamples = 31\nvalue = 3.984'),
#  Text(0.32216494845360827, 0.2777777777777778, 'x[2] <= 4.31\nsquared_error = 0.145\nsamples = 9\nvalue = 4.809'),
#  Text(0.31958762886597936, 0.16666666666666666, 'squared_error = -0.0\nsamples = 7\nvalue = 5.0'),
#  Text(0.3247422680412371, 0.16666666666666666, 'x[7] <= -122.465\nsquared_error = 0.078\nsamples = 2\nvalue = 4.14'),
#  Text(0.32216494845360827, 0.05555555555555555, 'squared_error = 0.0\nsamples = 1\nvalue = 4.42'),
#  Text(0.327319587628866, 0.05555555555555555, 'squared_error = -0.0\nsamples = 1\nvalue = 3.861'),
#  Text(0.3402061855670103, 0.2777777777777778, 'x[6] <= 34.1\nsquared_error = 0.885\nsamples = 22\nvalue = 3.647'),
#  Text(0.33505154639175255, 0.16666666666666666, 'x[5] <= 1.619\nsquared_error = 0.55\nsamples = 17\nvalue = 3.957'),
#  Text(0.3324742268041237, 0.05555555555555555, 'squared_error = 0.31\nsamples = 6\nvalue = 4.454'),
#  Text(0.33762886597938147, 0.05555555555555555, 'squared_error = 0.473\nsamples = 11\nvalue = 3.686'),
#  Text(0.34536082474226804, 0.16666666666666666, 'x[4] <= 1893.0\nsquared_error = 0.577\nsamples = 5\nvalue = 2.59'),
#  Text(0.3427835051546392, 0.05555555555555555, 'squared_error = 0.149\nsamples = 4\nvalue = 2.251'),
#  Text(0.3479381443298969, 0.05555555555555555, 'squared_error = 0.0\nsamples = 1\nvalue = 3.943'),
#  Text(0.3711340206185567, 0.3888888888888889, 'x[0] <= 3.342\nsquared_error = 1.002\nsamples = 161\nvalue = 2.618'),
#  Text(0.36082474226804123, 0.2777777777777778, 'x[2] <= 5.031\nsquared_error = 0.497\nsamples = 61\nvalue = 2.042'),
#  Text(0.3556701030927835, 0.16666666666666666, 'x[7] <= -117.905\nsquared_error = 0.378\nsamples = 39\nvalue = 2.321'),
#  Text(0.35309278350515466, 0.05555555555555555, 'squared_error = 0.346\nsamples = 36\nvalue = 2.382'),
#  Text(0.3582474226804124, 0.05555555555555555, 'squared_error = 0.179\nsamples = 3\nvalue = 1.587'),
#  Text(0.36597938144329895, 0.16666666666666666, 'x[1] <= 44.0\nsquared_error = 0.324\nsamples = 22\nvalue = 1.546'),
#  Text(0.3634020618556701, 0.05555555555555555, 'squared_error = 0.23\nsamples = 15\nvalue = 1.348'),
#  Text(0.36855670103092786, 0.05555555555555555, 'squared_error = 0.261\nsamples = 7\nvalue = 1.97'),
#  Text(0.38144329896907214, 0.2777777777777778, 'x[6] <= 38.02\nsquared_error = 0.984\nsamples = 100\nvalue = 2.97'),
#  Text(0.37628865979381443, 0.16666666666666666, 'x[0] <= 4.082\nsquared_error = 0.779\nsamples = 89\nvalue = 3.138'),
#  Text(0.37371134020618557, 0.05555555555555555, 'squared_error = 0.667\nsamples = 52\nvalue = 2.907'),
#  Text(0.3788659793814433, 0.05555555555555555, 'squared_error = 0.757\nsamples = 37\nvalue = 3.462'),
#  Text(0.3865979381443299, 0.16666666666666666, 'x[0] <= 4.46\nsquared_error = 0.568\nsamples = 11\nvalue = 1.611'),
#  Text(0.38402061855670105, 0.05555555555555555, 'squared_error = 0.184\nsamples = 9\nvalue = 1.333'),
#  Text(0.38917525773195877, 0.05555555555555555, 'squared_error = 0.385\nsamples = 2\nvalue = 2.862'),
#  Text(0.46681701030927836, 0.6111111111111112, 'x[0] <= 3.915\nsquared_error = 0.42\nsamples = 934\nvalue = 1.837'),
#  Text(0.42847938144329895, 0.5, 'x[6] <= 37.925\nsquared_error = 0.342\nsamples = 522\nvalue = 1.667'),
#  Text(0.41237113402061853, 0.3888888888888889, 'x[7] <= -121.52\nsquared_error = 0.352\nsamples = 446\nvalue = 1.73'),
#  Text(0.4020618556701031, 0.2777777777777778, 'x[7] <= -122.405\nsquared_error = 0.332\nsamples = 74\nvalue = 2.2'),
#  Text(0.39690721649484534, 0.16666666666666666, 'x[6] <= 37.74\nsquared_error = 0.122\nsamples = 15\nvalue = 2.807'),
#  Text(0.3943298969072165, 0.05555555555555555, 'squared_error = 0.037\nsamples = 8\nvalue = 2.534'),
#  Text(0.39948453608247425, 0.05555555555555555, 'squared_error = 0.037\nsamples = 7\nvalue = 3.119'),
#  Text(0.4072164948453608, 0.16666666666666666, 'x[1] <= 25.5\nsquared_error = 0.268\nsamples = 59\nvalue = 2.046'),
#  Text(0.40463917525773196, 0.05555555555555555, 'squared_error = 0.299\nsamples = 16\nvalue = 2.502'),
#  Text(0.4097938144329897, 0.05555555555555555, 'squared_error = 0.15\nsamples = 43\nvalue = 1.877'),
#  Text(0.422680412371134, 0.2777777777777778, 'x[6] <= 34.465\nsquared_error = 0.304\nsamples = 372\nvalue = 1.637'),
#  Text(0.4175257731958763, 0.16666666666666666, 'x[7] <= -117.69\nsquared_error = 0.27\nsamples = 294\nvalue = 1.744'),
#  Text(0.41494845360824745, 0.05555555555555555, 'squared_error = 0.23\nsamples = 213\nvalue = 1.9'),
#  Text(0.42010309278350516, 0.05555555555555555, 'squared_error = 0.145\nsamples = 81\nvalue = 1.334'),
#  Text(0.42783505154639173, 0.16666666666666666, 'x[7] <= -120.08\nsquared_error = 0.222\nsamples = 78\nvalue = 1.232'),
#  Text(0.4252577319587629, 0.05555555555555555, 'squared_error = 0.221\nsamples = 35\nvalue = 1.542'),
#  Text(0.43041237113402064, 0.05555555555555555, 'squared_error = 0.081\nsamples = 43\nvalue = 0.98'),
#  Text(0.44458762886597936, 0.3888888888888889, 'x[1] <= 8.5\nsquared_error = 0.114\nsamples = 76\nvalue = 1.292'),
#  Text(0.43556701030927836, 0.2777777777777778, 'x[0] <= 3.122\nsquared_error = 0.034\nsamples = 4\nvalue = 1.906'),
#  Text(0.4329896907216495, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 1.625'),
#  Text(0.4381443298969072, 0.16666666666666666, 'x[1] <= 6.0\nsquared_error = 0.01\nsamples = 3\nvalue = 2.0'),
#  Text(0.43556701030927836, 0.05555555555555555, 'squared_error = 0.0\nsamples = 1\nvalue = 2.138'),
#  Text(0.44072164948453607, 0.05555555555555555, 'squared_error = 0.0\nsamples = 2\nvalue = 1.93'),
#  Text(0.4536082474226804, 0.2777777777777778, 'x[4] <= 747.0\nsquared_error = 0.097\nsamples = 72\nvalue = 1.258'),
#  Text(0.4484536082474227, 0.16666666666666666, 'x[0] <= 3.452\nsquared_error = 0.085\nsamples = 21\nvalue = 1.109'),
#  Text(0.44587628865979384, 0.05555555555555555, 'squared_error = 0.012\nsamples = 12\nvalue = 0.926'),
#  Text(0.45103092783505155, 0.05555555555555555, 'squared_error = 0.079\nsamples = 9\nvalue = 1.352'),
#  Text(0.4587628865979381, 0.16666666666666666, 'x[7] <= -122.415\nsquared_error = 0.089\nsamples = 51\nvalue = 1.32'),
#  Text(0.45618556701030927, 0.05555555555555555, 'squared_error = 0.111\nsamples = 11\nvalue = 1.518'),
#  Text(0.46134020618556704, 0.05555555555555555, 'squared_error = 0.069\nsamples = 40\nvalue = 1.265'),
#  Text(0.5051546391752577, 0.5, 'x[7] <= -121.905\nsquared_error = 0.436\nsamples = 412\nvalue = 2.053'),
#  Text(0.4845360824742268, 0.3888888888888889, 'x[6] <= 37.785\nsquared_error = 0.388\nsamples = 93\nvalue = 2.446'),
#  Text(0.4742268041237113, 0.2777777777777778, 'x[5] <= 2.857\nsquared_error = 0.347\nsamples = 61\nvalue = 2.648'),
#  Text(0.4690721649484536, 0.16666666666666666, 'x[7] <= -122.275\nsquared_error = 0.335\nsamples = 34\nvalue = 2.899'),
#  Text(0.46649484536082475, 0.05555555555555555, 'squared_error = 0.159\nsamples = 11\nvalue = 3.271'),
#  Text(0.47164948453608246, 0.05555555555555555, 'squared_error = 0.321\nsamples = 23\nvalue = 2.721'),
#  Text(0.4793814432989691, 0.16666666666666666, 'x[5] <= 3.91\nsquared_error = 0.184\nsamples = 27\nvalue = 2.333'),
#  Text(0.47680412371134023, 0.05555555555555555, 'squared_error = 0.139\nsamples = 25\nvalue = 2.4'),
#  Text(0.48195876288659795, 0.05555555555555555, 'squared_error = 0.0\nsamples = 2\nvalue = 1.502'),
#  Text(0.4948453608247423, 0.2777777777777778, 'x[2] <= 6.158\nsquared_error = 0.238\nsamples = 32\nvalue = 2.06'),
#  Text(0.4896907216494845, 0.16666666666666666, 'x[5] <= 3.01\nsquared_error = 0.109\nsamples = 20\nvalue = 1.849'),
#  Text(0.48711340206185566, 0.05555555555555555, 'squared_error = 0.071\nsamples = 16\nvalue = 1.957'),
#  Text(0.49226804123711343, 0.05555555555555555, 'squared_error = 0.025\nsamples = 4\nvalue = 1.418'),
#  Text(0.5, 0.16666666666666666, 'x[6] <= 39.69\nsquared_error = 0.256\nsamples = 12\nvalue = 2.411'),
#  Text(0.49742268041237114, 0.05555555555555555, 'squared_error = 0.154\nsamples = 11\nvalue = 2.513'),
#  Text(0.5025773195876289, 0.05555555555555555, 'squared_error = -0.0\nsamples = 1\nvalue = 1.289'),
#  Text(0.5257731958762887, 0.3888888888888889, 'x[6] <= 34.5\nsquared_error = 0.392\nsamples = 319\nvalue = 1.939'),
#  Text(0.5154639175257731, 0.2777777777777778, 'x[7] <= -118.105\nsquared_error = 0.382\nsamples = 226\nvalue = 2.071'),
#  Text(0.5103092783505154, 0.16666666666666666, 'x[2] <= 5.349\nsquared_error = 0.424\nsamples = 79\nvalue = 2.37'),
#  Text(0.5077319587628866, 0.05555555555555555, 'squared_error = 0.197\nsamples = 31\nvalue = 2.06'),
#  Text(0.5128865979381443, 0.05555555555555555, 'squared_error = 0.469\nsamples = 48\nvalue = 2.57'),
#  Text(0.520618556701031, 0.16666666666666666, 'x[4] <= 272.5\nsquared_error = 0.286\nsamples = 147\nvalue = 1.91'),
#  Text(0.5180412371134021, 0.05555555555555555, 'squared_error = 1.41\nsamples = 2\nvalue = 3.813'),
#  Text(0.5231958762886598, 0.05555555555555555, 'squared_error = 0.22\nsamples = 145\nvalue = 1.884'),
#  Text(0.5360824742268041, 0.2777777777777778, 'x[7] <= -119.925\nsquared_error = 0.269\nsamples = 93\nvalue = 1.617'),
#  Text(0.5309278350515464, 0.16666666666666666, 'x[6] <= 37.325\nsquared_error = 0.251\nsamples = 69\nvalue = 1.772'),
#  Text(0.5283505154639175, 0.05555555555555555, 'squared_error = 0.223\nsamples = 16\nvalue = 2.238'),
#  Text(0.5335051546391752, 0.05555555555555555, 'squared_error = 0.174\nsamples = 53\nvalue = 1.632'),
#  Text(0.5412371134020618, 0.16666666666666666, 'x[2] <= 6.095\nsquared_error = 0.051\nsamples = 24\nvalue = 1.171'),
#  Text(0.538659793814433, 0.05555555555555555, 'squared_error = 0.008\nsamples = 9\nvalue = 1.005'),
#  Text(0.5438144329896907, 0.05555555555555555, 'squared_error = 0.051\nsamples = 15\nvalue = 1.271'),
#  Text(0.8035599226804123, 0.8333333333333334, 'x[0] <= 6.291\nsquared_error = 1.303\nsamples = 629\nvalue = 3.295'),
#  Text(0.6849226804123711, 0.7222222222222222, 'x[5] <= 2.584\nsquared_error = 0.924\nsamples = 370\nvalue = 2.774'),
#  Text(0.6124355670103093, 0.6111111111111112, 'x[1] <= 16.5\nsquared_error = 1.011\nsamples = 97\nvalue = 3.589'),
#  Text(0.5811855670103093, 0.5, 'x[2] <= 6.296\nsquared_error = 0.192\nsamples = 18\nvalue = 2.62'),
#  Text(0.5670103092783505, 0.3888888888888889, 'x[4] <= 1601.5\nsquared_error = 0.147\nsamples = 14\nvalue = 2.493'),
#  Text(0.5567010309278351, 0.2777777777777778, 'x[2] <= 5.381\nsquared_error = 0.143\nsamples = 8\nvalue = 2.31'),
#  Text(0.5515463917525774, 0.16666666666666666, 'x[0] <= 5.364\nsquared_error = 0.019\nsamples = 3\nvalue = 1.891'),
#  Text(0.5489690721649485, 0.05555555555555555, 'squared_error = 0.002\nsamples = 2\nvalue = 1.799'),
#  Text(0.5541237113402062, 0.05555555555555555, 'squared_error = 0.0\nsamples = 1\nvalue = 2.075'),
#  Text(0.5618556701030928, 0.16666666666666666, 'x[1] <= 15.0\nsquared_error = 0.049\nsamples = 5\nvalue = 2.562'),
#  Text(0.5592783505154639, 0.05555555555555555, 'squared_error = 0.002\nsamples = 4\nvalue = 2.452'),
#  Text(0.5644329896907216, 0.05555555555555555, 'squared_error = -0.0\nsamples = 1\nvalue = 3.0'),
#  Text(0.5773195876288659, 0.2777777777777778, 'x[2] <= 5.055\nsquared_error = 0.048\nsamples = 6\nvalue = 2.738'),
#  Text(0.5721649484536082, 0.16666666666666666, 'x[3] <= 1.184\nsquared_error = 0.002\nsamples = 3\nvalue = 2.94'),
#  Text(0.5695876288659794, 0.05555555555555555, 'squared_error = 0.0\nsamples = 2\nvalue = 2.972'),
#  Text(0.5747422680412371, 0.05555555555555555, 'squared_error = 0.0\nsamples = 1\nvalue = 2.875'),
#  Text(0.5824742268041238, 0.16666666666666666, 'x[3] <= 1.057\nsquared_error = 0.011\nsamples = 3\nvalue = 2.536'),
#  Text(0.5798969072164949, 0.05555555555555555, 'squared_error = 0.0\nsamples = 1\nvalue = 2.393'),
#  Text(0.5850515463917526, 0.05555555555555555, 'squared_error = 0.002\nsamples = 2\nvalue = 2.607'),
#  Text(0.595360824742268, 0.3888888888888889, 'x[1] <= 10.0\nsquared_error = 0.097\nsamples = 4\nvalue = 3.061'),
#  Text(0.5902061855670103, 0.2777777777777778, 'x[4] <= 1256.0\nsquared_error = 0.005\nsamples = 2\nvalue = 2.786'),
#  Text(0.5876288659793815, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 2.716'),
#  Text(0.5927835051546392, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 2.856'),
#  Text(0.6005154639175257, 0.2777777777777778, 'x[0] <= 5.871\nsquared_error = 0.037\nsamples = 2\nvalue = 3.336'),
#  Text(0.5979381443298969, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 3.529'),
#  Text(0.6030927835051546, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 3.144'),
#  Text(0.6436855670103093, 0.5, 'x[6] <= 34.15\nsquared_error = 0.935\nsamples = 79\nvalue = 3.81'),
#  Text(0.6237113402061856, 0.3888888888888889, 'x[5] <= 2.161\nsquared_error = 0.694\nsamples = 37\nvalue = 4.256'),
#  Text(0.6134020618556701, 0.2777777777777778, 'x[2] <= 4.657\nsquared_error = 0.056\nsamples = 15\nvalue = 4.85'),
#  Text(0.6082474226804123, 0.16666666666666666, 'x[6] <= 33.97\nsquared_error = 0.067\nsamples = 4\nvalue = 4.615'),
#  Text(0.6056701030927835, 0.05555555555555555, 'squared_error = 0.023\nsamples = 2\nvalue = 4.849'),
#  Text(0.6108247422680413, 0.05555555555555555, 'squared_error = 0.001\nsamples = 2\nvalue = 4.38'),
#  Text(0.6185567010309279, 0.16666666666666666, 'x[6] <= 33.565\nsquared_error = 0.025\nsamples = 11\nvalue = 4.936'),
#  Text(0.615979381443299, 0.05555555555555555, 'squared_error = 0.0\nsamples = 1\nvalue = 4.456'),
#  Text(0.6211340206185567, 0.05555555555555555, 'squared_error = 0.002\nsamples = 10\nvalue = 4.984'),
#  Text(0.634020618556701, 0.2777777777777778, 'x[1] <= 20.0\nsquared_error = 0.724\nsamples = 22\nvalue = 3.851'),
#  Text(0.6288659793814433, 0.16666666666666666, 'x[3] <= 0.981\nsquared_error = 0.278\nsamples = 3\nvalue = 2.413'),
#  Text(0.6262886597938144, 0.05555555555555555, 'squared_error = 0.0\nsamples = 1\nvalue = 3.1'),
#  Text(0.6314432989690721, 0.05555555555555555, 'squared_error = 0.063\nsamples = 2\nvalue = 2.07'),
#  Text(0.6391752577319587, 0.16666666666666666, 'x[7] <= -117.265\nsquared_error = 0.417\nsamples = 19\nvalue = 4.077'),
#  Text(0.6365979381443299, 0.05555555555555555, 'squared_error = 0.313\nsamples = 15\nvalue = 3.877'),
#  Text(0.6417525773195877, 0.05555555555555555, 'squared_error = 0.086\nsamples = 4\nvalue = 4.831'),
#  Text(0.663659793814433, 0.3888888888888889, 'x[7] <= -122.085\nsquared_error = 0.817\nsamples = 42\nvalue = 3.417'),
#  Text(0.654639175257732, 0.2777777777777778, 'x[2] <= 7.5\nsquared_error = 0.461\nsamples = 25\nvalue = 3.754'),
#  Text(0.6494845360824743, 0.16666666666666666, 'x[0] <= 5.579\nsquared_error = 0.396\nsamples = 23\nvalue = 3.664'),
#  Text(0.6469072164948454, 0.05555555555555555, 'squared_error = 0.364\nsamples = 15\nvalue = 3.453'),
#  Text(0.6520618556701031, 0.05555555555555555, 'squared_error = 0.216\nsamples = 8\nvalue = 4.06'),
#  Text(0.6597938144329897, 0.16666666666666666, 'x[5] <= 2.035\nsquared_error = 0.045\nsamples = 2\nvalue = 4.789'),
#  Text(0.6572164948453608, 0.05555555555555555, 'squared_error = 0.0\nsamples = 1\nvalue = 5.0'),
#  Text(0.6623711340206185, 0.05555555555555555, 'squared_error = 0.0\nsamples = 1\nvalue = 4.578'),
#  Text(0.6726804123711341, 0.2777777777777778, 'x[3] <= 1.071\nsquared_error = 0.926\nsamples = 17\nvalue = 2.92'),
#  Text(0.6701030927835051, 0.16666666666666666, 'x[0] <= 5.499\nsquared_error = 0.697\nsamples = 16\nvalue = 2.79'),
#  Text(0.6675257731958762, 0.05555555555555555, 'squared_error = 0.561\nsamples = 7\nvalue = 2.233'),
#  Text(0.6726804123711341, 0.05555555555555555, 'squared_error = 0.373\nsamples = 9\nvalue = 3.224'),
#  Text(0.6752577319587629, 0.16666666666666666, 'squared_error = -0.0\nsamples = 1\nvalue = 5.0'),
#  Text(0.757409793814433, 0.6111111111111112, 'x[5] <= 3.128\nsquared_error = 0.574\nsamples = 273\nvalue = 2.485'),
#  Text(0.7164948453608248, 0.5, 'x[1] <= 32.5\nsquared_error = 0.633\nsamples = 167\nvalue = 2.701'),
#  Text(0.6958762886597938, 0.3888888888888889, 'x[6] <= 38.49\nsquared_error = 0.478\nsamples = 109\nvalue = 2.509'),
#  Text(0.6855670103092784, 0.2777777777777778, 'x[1] <= 16.5\nsquared_error = 0.437\nsamples = 101\nvalue = 2.575'),
#  Text(0.6804123711340206, 0.16666666666666666, 'x[6] <= 34.04\nsquared_error = 0.614\nsamples = 35\nvalue = 2.267'),
#  Text(0.6778350515463918, 0.05555555555555555, 'squared_error = 0.555\nsamples = 19\nvalue = 2.643'),
#  Text(0.6829896907216495, 0.05555555555555555, 'squared_error = 0.318\nsamples = 16\nvalue = 1.821'),
#  Text(0.6907216494845361, 0.16666666666666666, 'x[6] <= 34.245\nsquared_error = 0.266\nsamples = 66\nvalue = 2.738'),
#  Text(0.6881443298969072, 0.05555555555555555, 'squared_error = 0.18\nsamples = 36\nvalue = 2.534'),
#  Text(0.6932989690721649, 0.05555555555555555, 'squared_error = 0.259\nsamples = 30\nvalue = 2.983'),
#  Text(0.7061855670103093, 0.2777777777777778, 'x[1] <= 21.0\nsquared_error = 0.272\nsamples = 8\nvalue = 1.687'),
#  Text(0.7010309278350515, 0.16666666666666666, 'x[3] <= 1.057\nsquared_error = 0.056\nsamples = 5\nvalue = 2.043'),
#  Text(0.6984536082474226, 0.05555555555555555, 'squared_error = 0.014\nsamples = 2\nvalue = 1.768'),
#  Text(0.7036082474226805, 0.05555555555555555, 'squared_error = 0.0\nsamples = 3\nvalue = 2.225'),
#  Text(0.711340206185567, 0.16666666666666666, 'x[7] <= -121.495\nsquared_error = 0.071\nsamples = 3\nvalue = 1.094'),
#  Text(0.7087628865979382, 0.05555555555555555, 'squared_error = 0.0\nsamples = 1\nvalue = 0.718'),
#  Text(0.7139175257731959, 0.05555555555555555, 'squared_error = 0.0\nsamples = 2\nvalue = 1.282'),
#  Text(0.7371134020618557, 0.3888888888888889, 'x[7] <= -118.345\nsquared_error = 0.726\nsamples = 58\nvalue = 3.062'),
#  Text(0.7268041237113402, 0.2777777777777778, 'x[2] <= 5.674\nsquared_error = 0.83\nsamples = 27\nvalue = 3.446'),
#  Text(0.7216494845360825, 0.16666666666666666, 'x[4] <= 1028.0\nsquared_error = 0.18\nsamples = 8\nvalue = 2.654'),
#  Text(0.7190721649484536, 0.05555555555555555, 'squared_error = 0.126\nsamples = 7\nvalue = 2.754'),
#  Text(0.7242268041237113, 0.05555555555555555, 'squared_error = 0.0\nsamples = 1\nvalue = 1.953'),
#  Text(0.7319587628865979, 0.16666666666666666, 'x[4] <= 898.5\nsquared_error = 0.728\nsamples = 19\nvalue = 3.779'),
#  Text(0.729381443298969, 0.05555555555555555, 'squared_error = 0.378\nsamples = 9\nvalue = 4.29'),
#  Text(0.7345360824742269, 0.05555555555555555, 'squared_error = 0.596\nsamples = 10\nvalue = 3.319'),
#  Text(0.7474226804123711, 0.2777777777777778, 'x[6] <= 34.115\nsquared_error = 0.394\nsamples = 31\nvalue = 2.727'),
#  Text(0.7422680412371134, 0.16666666666666666, 'x[1] <= 35.5\nsquared_error = 0.204\nsamples = 20\nvalue = 2.448'),
#  Text(0.7396907216494846, 0.05555555555555555, 'squared_error = 0.26\nsamples = 7\nvalue = 2.833'),
#  Text(0.7448453608247423, 0.05555555555555555, 'squared_error = 0.051\nsamples = 13\nvalue = 2.241'),
#  Text(0.7525773195876289, 0.16666666666666666, 'x[1] <= 38.0\nsquared_error = 0.341\nsamples = 11\nvalue = 3.235'),
#  Text(0.75, 0.05555555555555555, 'squared_error = 0.084\nsamples = 6\nvalue = 2.827'),
#  Text(0.7551546391752577, 0.05555555555555555, 'squared_error = 0.209\nsamples = 5\nvalue = 3.725'),
#  Text(0.7983247422680413, 0.5, 'x[1] <= 18.5\nsquared_error = 0.291\nsamples = 106\nvalue = 2.145'),
#  Text(0.7783505154639175, 0.3888888888888889, 'x[0] <= 5.694\nsquared_error = 0.193\nsamples = 50\nvalue = 1.951'),
#  Text(0.7680412371134021, 0.2777777777777778, 'x[3] <= 1.067\nsquared_error = 0.183\nsamples = 36\nvalue = 1.818'),
#  Text(0.7628865979381443, 0.16666666666666666, 'x[7] <= -116.925\nsquared_error = 0.112\nsamples = 29\nvalue = 1.711'),
#  Text(0.7603092783505154, 0.05555555555555555, 'squared_error = 0.094\nsamples = 28\nvalue = 1.683'),
#  Text(0.7654639175257731, 0.05555555555555555, 'squared_error = 0.0\nsamples = 1\nvalue = 2.489'),
#  Text(0.7731958762886598, 0.16666666666666666, 'x[0] <= 5.284\nsquared_error = 0.233\nsamples = 7\nvalue = 2.261'),
#  Text(0.770618556701031, 0.05555555555555555, 'squared_error = 0.065\nsamples = 3\nvalue = 1.851'),
#  Text(0.7757731958762887, 0.05555555555555555, 'squared_error = 0.139\nsamples = 4\nvalue = 2.568'),
#  Text(0.788659793814433, 0.2777777777777778, 'x[6] <= 38.01\nsquared_error = 0.056\nsamples = 14\nvalue = 2.294'),
#  Text(0.7835051546391752, 0.16666666666666666, 'x[0] <= 5.841\nsquared_error = 0.018\nsamples = 10\nvalue = 2.419'),
#  Text(0.7809278350515464, 0.05555555555555555, 'squared_error = 0.0\nsamples = 2\nvalue = 2.196'),
#  Text(0.7860824742268041, 0.05555555555555555, 'squared_error = 0.007\nsamples = 8\nvalue = 2.475'),
#  Text(0.7938144329896907, 0.16666666666666666, 'x[4] <= 2793.0\nsquared_error = 0.014\nsamples = 4\nvalue = 1.983'),
#  Text(0.7912371134020618, 0.05555555555555555, 'squared_error = 0.006\nsamples = 3\nvalue = 2.04'),
#  Text(0.7963917525773195, 0.05555555555555555, 'squared_error = 0.0\nsamples = 1\nvalue = 1.81'),
#  Text(0.8182989690721649, 0.3888888888888889, 'x[4] <= 1140.0\nsquared_error = 0.314\nsamples = 56\nvalue = 2.317'),
#  Text(0.8092783505154639, 0.2777777777777778, 'x[4] <= 168.0\nsquared_error = 0.444\nsamples = 19\nvalue = 2.005'),
#  Text(0.8041237113402062, 0.16666666666666666, 'x[1] <= 30.5\nsquared_error = 0.01\nsamples = 2\nvalue = 3.4'),
#  Text(0.8015463917525774, 0.05555555555555555, 'squared_error = 0.0\nsamples = 1\nvalue = 3.3'),
#  Text(0.8067010309278351, 0.05555555555555555, 'squared_error = 0.0\nsamples = 1\nvalue = 3.5'),
#  Text(0.8144329896907216, 0.16666666666666666, 'x[6] <= 33.26\nsquared_error = 0.24\nsamples = 17\nvalue = 1.841'),
#  Text(0.8118556701030928, 0.05555555555555555, 'squared_error = 0.0\nsamples = 1\nvalue = 0.996'),
#  Text(0.8170103092783505, 0.05555555555555555, 'squared_error = 0.207\nsamples = 16\nvalue = 1.894'),
#  Text(0.8273195876288659, 0.2777777777777778, 'x[1] <= 36.5\nsquared_error = 0.172\nsamples = 37\nvalue = 2.477'),
#  Text(0.8247422680412371, 0.16666666666666666, 'x[7] <= -122.13\nsquared_error = 0.112\nsamples = 36\nvalue = 2.436'),
#  Text(0.8221649484536082, 0.05555555555555555, 'squared_error = 0.044\nsamples = 5\nvalue = 2.833'),
#  Text(0.8273195876288659, 0.05555555555555555, 'squared_error = 0.093\nsamples = 31\nvalue = 2.371'),
#  Text(0.8298969072164949, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 3.979'),
#  Text(0.9221971649484536, 0.7222222222222222, 'x[0] <= 7.748\nsquared_error = 0.904\nsamples = 259\nvalue = 4.04'),
#  Text(0.8775773195876289, 0.6111111111111112, 'x[1] <= 25.5\nsquared_error = 0.787\nsamples = 147\nvalue = 3.609'),
#  Text(0.8472938144329897, 0.5, 'x[2] <= 6.337\nsquared_error = 0.458\nsamples = 77\nvalue = 3.2'),
#  Text(0.8350515463917526, 0.3888888888888889, 'x[5] <= 2.328\nsquared_error = 0.209\nsamples = 10\nvalue = 2.597'),
#  Text(0.8324742268041238, 0.2777777777777778, 'squared_error = 0.0\nsamples = 1\nvalue = 1.556'),
#  Text(0.8376288659793815, 0.2777777777777778, 'x[1] <= 21.0\nsquared_error = 0.098\nsamples = 9\nvalue = 2.712'),
#  Text(0.8350515463917526, 0.16666666666666666, 'x[6] <= 33.87\nsquared_error = 0.032\nsamples = 8\nvalue = 2.619'),
#  Text(0.8324742268041238, 0.05555555555555555, 'squared_error = 0.022\nsamples = 6\nvalue = 2.548'),
#  Text(0.8376288659793815, 0.05555555555555555, 'squared_error = 0.003\nsamples = 2\nvalue = 2.832'),
#  Text(0.8402061855670103, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 3.459'),
#  Text(0.8595360824742269, 0.3888888888888889, 'x[7] <= -117.22\nsquared_error = 0.433\nsamples = 67\nvalue = 3.29'),
#  Text(0.8505154639175257, 0.2777777777777778, 'x[5] <= 3.156\nsquared_error = 0.403\nsamples = 60\nvalue = 3.369'),
#  Text(0.845360824742268, 0.16666666666666666, 'x[1] <= 10.0\nsquared_error = 0.385\nsamples = 38\nvalue = 3.551'),
#  Text(0.8427835051546392, 0.05555555555555555, 'squared_error = 0.147\nsamples = 11\nvalue = 3.177'),
#  Text(0.8479381443298969, 0.05555555555555555, 'squared_error = 0.402\nsamples = 27\nvalue = 3.704'),
#  Text(0.8556701030927835, 0.16666666666666666, 'x[2] <= 6.656\nsquared_error = 0.277\nsamples = 22\nvalue = 3.054'),
#  Text(0.8530927835051546, 0.05555555555555555, 'squared_error = 0.513\nsamples = 2\nvalue = 4.284'),
#  Text(0.8582474226804123, 0.05555555555555555, 'squared_error = 0.087\nsamples = 20\nvalue = 2.931'),
#  Text(0.8685567010309279, 0.2777777777777778, 'x[0] <= 7.666\nsquared_error = 0.179\nsamples = 7\nvalue = 2.613'),
#  Text(0.865979381443299, 0.16666666666666666, 'x[6] <= 32.945\nsquared_error = 0.058\nsamples = 6\nvalue = 2.76'),
#  Text(0.8634020618556701, 0.05555555555555555, 'squared_error = 0.022\nsamples = 3\nvalue = 2.953'),
#  Text(0.8685567010309279, 0.05555555555555555, 'squared_error = 0.019\nsamples = 3\nvalue = 2.566'),
#  Text(0.8711340206185567, 0.16666666666666666, 'squared_error = -0.0\nsamples = 1\nvalue = 1.732'),
#  Text(0.907860824742268, 0.5, 'x[6] <= 37.61\nsquared_error = 0.761\nsamples = 70\nvalue = 4.059'),
#  Text(0.8878865979381443, 0.3888888888888889, 'x[5] <= 2.643\nsquared_error = 0.624\nsamples = 52\nvalue = 4.276'),
#  Text(0.8788659793814433, 0.2777777777777778, 'x[2] <= 5.184\nsquared_error = 0.119\nsamples = 24\nvalue = 4.775'),
#  Text(0.8762886597938144, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 3.728'),
#  Text(0.8814432989690721, 0.16666666666666666, 'x[1] <= 28.5\nsquared_error = 0.075\nsamples = 23\nvalue = 4.821'),
#  Text(0.8788659793814433, 0.05555555555555555, 'squared_error = 0.0\nsamples = 1\nvalue = 4.03'),
#  Text(0.884020618556701, 0.05555555555555555, 'squared_error = 0.048\nsamples = 22\nvalue = 4.856'),
#  Text(0.8969072164948454, 0.2777777777777778, 'x[6] <= 37.33\nsquared_error = 0.662\nsamples = 28\nvalue = 3.849'),
#  Text(0.8917525773195877, 0.16666666666666666, 'x[2] <= 6.602\nsquared_error = 0.575\nsamples = 22\nvalue = 3.617'),
#  Text(0.8891752577319587, 0.05555555555555555, 'squared_error = 0.045\nsamples = 10\nvalue = 3.233'),
#  Text(0.8943298969072165, 0.05555555555555555, 'squared_error = 0.791\nsamples = 12\nvalue = 3.938'),
#  Text(0.9020618556701031, 0.16666666666666666, 'x[1] <= 34.5\nsquared_error = 0.058\nsamples = 6\nvalue = 4.7'),
#  Text(0.8994845360824743, 0.05555555555555555, 'squared_error = 0.02\nsamples = 4\nvalue = 4.55'),
#  Text(0.904639175257732, 0.05555555555555555, 'squared_error = -0.0\nsamples = 2\nvalue = 5.0'),
#  Text(0.9278350515463918, 0.3888888888888889, 'x[4] <= 601.5\nsquared_error = 0.623\nsamples = 18\nvalue = 3.429'),
#  Text(0.9175257731958762, 0.2777777777777778, 'x[6] <= 37.81\nsquared_error = 0.289\nsamples = 4\nvalue = 2.372'),
#  Text(0.9123711340206185, 0.16666666666666666, 'x[5] <= 2.541\nsquared_error = 0.033\nsamples = 2\nvalue = 1.904'),
#  Text(0.9097938144329897, 0.05555555555555555, 'squared_error = 0.0\nsamples = 1\nvalue = 1.722'),
#  Text(0.9149484536082474, 0.05555555555555555, 'squared_error = 0.0\nsamples = 1\nvalue = 2.085'),
#  Text(0.9226804123711341, 0.16666666666666666, 'x[2] <= 6.683\nsquared_error = 0.106\nsamples = 2\nvalue = 2.842'),
#  Text(0.9201030927835051, 0.05555555555555555, 'squared_error = 0.0\nsamples = 1\nvalue = 3.167'),
#  Text(0.9252577319587629, 0.05555555555555555, 'squared_error = 0.0\nsamples = 1\nvalue = 2.516'),
#  Text(0.9381443298969072, 0.2777777777777778, 'x[2] <= 5.648\nsquared_error = 0.308\nsamples = 14\nvalue = 3.731'),
#  Text(0.9329896907216495, 0.16666666666666666, 'x[0] <= 6.83\nsquared_error = 0.049\nsamples = 2\nvalue = 4.78'),
#  Text(0.9304123711340206, 0.05555555555555555, 'squared_error = 0.0\nsamples = 1\nvalue = 5.0'),
#  Text(0.9355670103092784, 0.05555555555555555, 'squared_error = -0.0\nsamples = 1\nvalue = 4.559'),
#  Text(0.9432989690721649, 0.16666666666666666, 'x[2] <= 7.413\nsquared_error = 0.138\nsamples = 12\nvalue = 3.557'),
#  Text(0.9407216494845361, 0.05555555555555555, 'squared_error = 0.051\nsamples = 7\nvalue = 3.328'),
#  Text(0.9458762886597938, 0.05555555555555555, 'squared_error = 0.084\nsamples = 5\nvalue = 3.876'),
#  Text(0.9668170103092784, 0.6111111111111112, 'x[4] <= 57.0\nsquared_error = 0.495\nsamples = 112\nvalue = 4.605'),
#  Text(0.9574742268041238, 0.5, 'x[5] <= 3.183\nsquared_error = 1.805\nsamples = 2\nvalue = 2.656'),
#  Text(0.9548969072164949, 0.3888888888888889, 'squared_error = 0.0\nsamples = 1\nvalue = 1.313'),
#  Text(0.9600515463917526, 0.3888888888888889, 'squared_error = 0.0\nsamples = 1\nvalue = 4.0'),
#  Text(0.976159793814433, 0.5, 'x[0] <= 10.017\nsquared_error = 0.401\nsamples = 110\nvalue = 4.64'),
#  Text(0.9652061855670103, 0.3888888888888889, 'x[1] <= 28.5\nsquared_error = 0.551\nsamples = 62\nvalue = 4.396'),
#  Text(0.9587628865979382, 0.2777777777777778, 'x[5] <= 2.991\nsquared_error = 0.617\nsamples = 34\nvalue = 4.029'),
#  Text(0.9536082474226805, 0.16666666666666666, 'x[0] <= 8.293\nsquared_error = 0.3\nsamples = 17\nvalue = 4.433'),
#  Text(0.9510309278350515, 0.05555555555555555, 'squared_error = 0.27\nsamples = 9\nvalue = 4.152'),
#  Text(0.9561855670103093, 0.05555555555555555, 'squared_error = 0.146\nsamples = 8\nvalue = 4.749'),
#  Text(0.9639175257731959, 0.16666666666666666, 'x[2] <= 7.917\nsquared_error = 0.608\nsamples = 17\nvalue = 3.625'),
#  Text(0.961340206185567, 0.05555555555555555, 'squared_error = 0.598\nsamples = 9\nvalue = 3.292'),
#  Text(0.9664948453608248, 0.05555555555555555, 'squared_error = 0.355\nsamples = 8\nvalue = 3.999'),
#  Text(0.9716494845360825, 0.2777777777777778, 'x[3] <= 0.887\nsquared_error = 0.107\nsamples = 28\nvalue = 4.843'),
#  Text(0.9690721649484536, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 3.833'),
#  Text(0.9742268041237113, 0.16666666666666666, 'x[4] <= 870.5\nsquared_error = 0.072\nsamples = 27\nvalue = 4.88'),
#  Text(0.9716494845360825, 0.05555555555555555, 'squared_error = -0.0\nsamples = 15\nvalue = 5.0'),
#  Text(0.9768041237113402, 0.05555555555555555, 'squared_error = 0.121\nsamples = 12\nvalue = 4.73'),
#  Text(0.9871134020618557, 0.3888888888888889, 'x[5] <= 2.047\nsquared_error = 0.032\nsamples = 48\nvalue = 4.955'),
#  Text(0.9845360824742269, 0.2777777777777778, 'squared_error = 0.0\nsamples = 1\nvalue = 4.0'),
#  Text(0.9896907216494846, 0.2777777777777778, 'x[6] <= 37.86\nsquared_error = 0.013\nsamples = 47\nvalue = 4.975'),
#  Text(0.9845360824742269, 0.16666666666666666, 'x[4] <= 2548.5\nsquared_error = 0.002\nsamples = 43\nvalue = 4.99'),
#  Text(0.9819587628865979, 0.05555555555555555, 'squared_error = -0.0\nsamples = 39\nvalue = 5.0'),
#  Text(0.9871134020618557, 0.05555555555555555, 'squared_error = 0.011\nsamples = 4\nvalue = 4.897'),
#  Text(0.9948453608247423, 0.16666666666666666, 'x[6] <= 37.905\nsquared_error = 0.102\nsamples = 4\nvalue = 4.815'),
#  Text(0.9922680412371134, 0.05555555555555555, 'squared_error = 0.0\nsamples = 1\nvalue = 4.261'),
#  Text(0.9974226804123711, 0.05555555555555555, 'squared_error = 0.0\nsamples = 3\nvalue = 5.0')]

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([0.57385366, 2.99564   , 1.53821818, ..., 4.43729143, 3.372801  ,
#        2.99564   ])

# %%
r2_score(y_test,y_pred)
# Out:
# 0.5405176127451384
